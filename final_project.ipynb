# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
carbon_df = pd.read_csv("CarbonDataEmissions.csv")
transportation_df = pd.read_csv("TransportationData.csv")

# %%
carbon_df.rename(columns={"Percent": "percent_change", "Absolute": "absolute_change"}, inplace=True)
carbon_df.head()
# Out:
#         State   2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0     Alabama  142.9  134.2  139.2  140.3  142.6  144.3  146.6  148.2  140.4
# 1      Alaska   44.4   43.5   43.7   43.7   46.9   48.2   45.9   44.2   39.6
# 2     Arizona   86.4   88.7   88.1   90.1   97.1   97.2  100.3  102.3  102.6
# 3    Arkansas   63.8   63.0   61.5   62.3   62.7   60.4   62.2   63.5   64.4
# 4  California  376.8  381.3  379.7  368.7  386.6  383.8  392.2  397.2  381.2
#
#    ...   2011   2012   2013   2014   2015   2016   2017   2018 percent_change  \
# 0  ...  130.3  123.6  121.1  123.4  120.0  114.8  109.5  113.3          -20.7
# 1  ...   37.8   36.8   34.8   34.5   35.5   34.0   34.4   35.1          -21.0
# 2  ...   97.2   95.0   99.0   97.1   94.7   90.7   90.3   93.9            8.7
# 3  ...   67.5   66.3   68.7   69.2   59.4   62.5   64.5   71.1           11.5
# 4  ...  340.9  346.6  348.2  344.0  351.0  352.3  355.3  356.6           -5.4
#
#   absolute_change
# ...

# %%
transportation_df.rename(columns={"Commute mode share (percent)": "commute_mode_share_percent"}, inplace=True)
transportation_df["commute_mode_share_percent"] = transportation_df["commute_mode_share_percent"] * 100
transportation_df.head()
# Out:
#         State     Mode  Year  commute_mode_share_percent
# 0     Alabama  Carpool  2000                        12.3
# 1      Alaska  Carpool  2000                        15.5
# 2     Arizona  Carpool  2000                        15.4
# 3    Arkansas  Carpool  2000                        14.1
# 4  California  Carpool  2000                        14.5

# %%
alt.renderers.enable('default')
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
alt.Chart(carbon_df).mark_bar().encode(
    alt.X('State'),
    alt.Y('percent_change'),
    color=alt.Color('percent_change', scale=alt.Scale(scheme='accent'), sort=alt.Sort()),
).properties(
    title='Carbon Emissions Percent Change 2000-2018'
)
# Out:
# alt.Chart(...)
